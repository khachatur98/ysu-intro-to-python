# %%
import numpy as np

# %% [markdown]
# ### Task 1: Solve the following system of linear equations using numpy [10 min, 0.5 points]
#
# $2x - 3y + z = -1$ \
# $x - y + 2z = -3$ \
# $3x + y - z = 9$

# %%
np.linalg.inv()

# %% [markdown]
# ### Task 2: Given the following matrix A, find the A^100000000001 [10 min, 0.5 points]
# ### (A @ A ..... @ A 100000000001 times) (1, ten zeros, 1)

# %%
theta = np.pi / 2

A = np.array(
    [
        [np.cos(theta), -np.sin(theta), 0],
        [np.sin(theta), np.cos(theta), 0],
        [0, 0, 1]
    ])

# %% [markdown]
# ### Task 3: Plot a polynomial function of degree 5 which has the following roots: -2, -1, 1.5, 2.5, 4
# ### [20 min, 1 points]
# Plot the function in the range [-3, 5] \
# Set y limits to [-50, 50] \
# Also plot the y = 0 line and the roots

# %% [markdown]
# ## Task 3: Plot a star-like shape with 5 points [10 min, 1 points]

# %% [markdown]
# ### Task 4: Plot the following parametric equation [10 min, 1 points]
# $x(t) = 2cos(t) + 5cos(2t/3)$ \
# $y(t) = 2sin(t) - 5sin(2t/3)$
#
# Hint: what is the periodicity of the function?
